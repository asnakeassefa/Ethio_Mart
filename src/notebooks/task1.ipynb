# %%
import pandas as pd
import re

# %%
def data_cleaning(df):
    # Check for NaN values in the 'Message' column
    print("Checking for NaN values in the 'Message' column:")
    nan_count = df['Message'].isnull().sum()
    print(f"Number of NaN values in 'Message' column: {nan_count}")

    # Drop NaN values
    df = df.dropna(subset=['Message'])
    print(df.info())
    return df

# %%
def message_clean(df):
    # Print the shape of the dataset after dropping NaN values in the "Message" column
    print(f"Dataset shape after dropping NaN values in 'Message' column: {df.shape}")

    # Define a function to remove emojis
    def remove_emojis(text):
        emoji_pattern = re.compile(
            "[" 
            "\U0001F600-\U0001F64F"  # emoticons
            "\U0001F300-\U0001F5FF"  # symbols & pictographs
            "\U0001F680-\U0001F6FF"  # transport & map symbols
            "\U0001F700-\U0001F77F"  # alchemical symbols
            "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
            "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
            "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
            "\U0001FA00-\U0001FA6F"  # Chess Symbols
            "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
            "\U00002702-\U000027B0"  # Dingbats
            "\U000024C2-\U0001F251" 
            "]+", 
            flags=re.UNICODE
        )
        return emoji_pattern.sub(r'', text)

    # Apply the function to the 'Message' column
    df['Message'] = df['Message'].apply(remove_emojis)

    # Display the updated DataFrame
    print("Updated DataFrame:")
    print(df.head())

    return df

# %%
def label_messages(df):
    # Define a function to label messages with entity types
    def label_message_utf8_with_birr(message):
        labeled_tokens = []
        
        # Tokenize the message
        tokens = re.findall(r'\S+', message)
        
        for token in tokens:
            # Check if token is a price (e.g., 500 ETB, $100, or ብር)
            if re.match(r'^\d+(\.\d{1,2})?$', token) or 'ETB' in token or 'ዋጋ' in token or '$' in token or 'ብር' in token:
                labeled_tokens.append(f"{token} B-PRICE")  # Assuming the first price token as B-PRICE
            # Check if token could be a location (e.g., cities or general location names)
            elif any(loc in token for loc in ['Addis Ababa', 'ለቡ', 'ለቡ መዳህኒዓለም', 'መገናኛ', 'ቦሌ', 'ሜክሲኮ']):
                labeled_tokens.append(f"{token} B-LOC")  # Assuming the first location token as B-LOC
            # Assume other tokens are part of a product name or general text
            else:
                labeled_tokens.append(f"{token} O")  # Outside any entity
                
        return "\n".join(labeled_tokens)

    # Sample 30-50 messages for labeling
    sample_size = 30
    sample_df = df.sample(n=sample_size)

    # Apply the labeling function to the sampled messages
    sample_df['Labeled_Message'] = sample_df['Message'].apply(label_message_utf8_with_birr)

    return sample_df

# %%
def label_telegram_data(df):
    # Display the labeled messages
    print("Sampled Labeled Messages:")
    print(df[['Message', 'Labeled_Message']])

    # Save the labeled dataset to a file in CoNLL format
    labeled_data_birr_path = 'labeled_telegram_product_price_location.txt'
    with open(labeled_data_birr_path, 'w', encoding='utf-8') as f:
        for index, row in df.iterrows():
            f.write(f"{row['Labeled_Message']}\n\n")

    print(f"Labeled data saved to {labeled_data_birr_path}")

    return labeled_data_birr_path

# %%
def main():
    # Load the dataset
    df = pd.read_csv('../../telegram_data.csv')
    print(df.head(5))

    # Data cleaning
    df = data_cleaning(df)

    # Message cleaning
    df = message_clean(df)

    # Label messages
    labeled_df = label_messages(df)

    # Label the entire dataset
    label_telegram_data(labeled_df)

# %%
main()
# Out:
#   Channel Title Channel Username    ID  \
# 0        ምርጥ ዕቃ        @MerttEka  6821
# 1        ምርጥ ዕቃ        @MerttEka  6820
# 2        ምርጥ ዕቃ        @MerttEka  6819
# 3        ምርጥ ዕቃ        @MerttEka  6818
# 4        ምርጥ ዕቃ        @MerttEka  6817
#
#                                              Message  \
# 0                                                NaN
# 1                                                NaN
# 2  📣 🔠🔠🔠🔠🔠🔠🔠 🔠🔠🔠🔠🔠\n\n✔️ ዘመናዊ በኤሌክትሮኒክስ የሚሰራ ሚዛን\...
# 3  📣 🔠🔠🔠🔠🔠 🔠🔠🔠🔠🔠🔠🔠🔠 🔠🔠🔠🔠🔠🔠\n\n✔️ ቦርጭ የሚሰበስብ\n✔️የቦ...
# 4  📣 Multi Functional Shoe and Hat Rack\n\n📎 ይሄንን...
#
#                         Date                 Media Path
# 0  2024-09-29 15:35:04+00:00  photos/@MerttEka_6821.jpg
# 1  2024-09-29 15:35:03+00:00  photos/@MerttEka_6820.jpg
# 2  2024-09-29 15:35:03+00:00  photos/@MerttEka_6819.jpg
# 3  2024-09-29 15:13:37+00:00  photos/@MerttEka_6818.jpg
# 4  2024-09-29 14:53:49+00:00                        NaN
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 1559
# <class 'pandas.core.frame.DataFrame'>
# Index: 4165 entries, 2 to 5710
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel Title     4165 non-null   object
#  1   Channel Username  4165 non-null   object
#  2   ID                4165 non-null   int64
#  3   Message           4165 non-null   object
#  4   Date              4165 non-null   object
#  5   Media Path        3080 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 227.8+ KB
# None
# Dataset shape after dropping NaN values in 'Message' column: (4165, 6)
# Updated DataFrame:
#   Channel Title Channel Username    ID  \
# 2        ምርጥ ዕቃ        @MerttEka  6819
# 3        ምርጥ ዕቃ        @MerttEka  6818
# 4        ምርጥ ዕቃ        @MerttEka  6817
# 5        ምርጥ ዕቃ        @MerttEka  6816
# 6        ምርጥ ዕቃ        @MerttEka  6815
#
#                                              Message  \
# 2    \n\n ዘመናዊ በኤሌክትሮኒክስ የሚሰራ ሚዛን\nእስከ 50 ኪሎ ይመዝና...
# 3     \n\n ቦርጭ የሚሰበስብ\nየቦርጭ ስብ የሚያቃጥል \n ማራኪ የሰውነ...
# 4   Multi Functional Shoe and Hat Rack\n\n ይሄንን t...
# 5   Multi Functional Shoe and Hat Rack\n\n ባለ ዘርፈ...
# 6   \n\n Breast Shell Milk Collector\n\n ይሄንን t.m...
#
#                         Date                 Media Path
# 2  2024-09-29 15:35:03+00:00  photos/@MerttEka_6819.jpg
# 3  2024-09-29 15:13:37+00:00  photos/@MerttEka_6818.jpg
# 4  2024-09-29 14:53:49+00:00                        NaN
# 5  2024-09-29 14:50:01+00:00  photos/@MerttEka_6816.jpg
# 6  2024-09-27 18:15:44+00:00                        NaN
# Sampled Labeled Messages:
#                                                 Message  \
# 1332   ልዩ የበዓል ቅናሽ\n\n Acrylic Salad Bowel\n\n የሰላጣና...
# 3968   0904944848\n 0911928738\n\n@ordermertteka1\n@...
# 2023   Room Humidifier\n\n 2 ሊትር ይይዛል\n ቤትዎን በጥሩ መአዛ...
# 5162  \n4.2 ሊትር መጠን ያለውን ማንኛውንም ጥብሳጥብስ፣ ቺፕስ፣ አሮስቶ እና...
# 1131    Non Stick  CREPE MAKER\n\nየቂጣ መጋገሪያ\n ለአሳንቡሳ...
# 144    SILVER CREST MULTIFUNCTIONAL KITCHEN MACHINE\...
# 2128   Kitchen Micro Fiber Towel\n\n የኪችን ፎጣ\n በከፍተኛ...
# 1358   Sonifer 2 in 1 Juice Blender\n\n የጁስ መፍጪያ\n 5...
# 4136  Foot bath and Massager\n የእግር ማጠቢያ እና ማሳጅ ማድረጊ...
# 4331  የካቻፕ መቀነሻ\n 150 ብር\n@ordermertteka1\nዘፍመሽ 3ኛ ፎ...
# 2647  Circular Mosquito Net\n ክብ አጎበር\n ቢንቢ እና በራሪ ነ...
# 516                                መልካም የዕረፍት ቀን ይሁንልዎት
# 3119   Wass Mitad\n    ዋስ ምጣድ\n  16 inch(41 cm)  ስፋት...
# 834    Creative 6 layer Shoe Rack\n\n ይሄንን t.me/Mert...
# 4996  htc pressure cooker\n 100% ከአልሙኒየም የተሰራ\n አስተማ...
# 2880                                    TOBI STEAM IRON
# 3485  Kitchen Tools Organizer\n የማንኪያ ሹካና ቢላ ማስቀመጪያ\...
# 3082   DOUBLE SIDE FRAYING PAN\n\n ከሴራሚክ የተሰራ\n  30c...
# 2333  Bright Round Oven\n የዳቦ መጋገሪያ\n 3 ወፍራም የአልሙኒየም...
# 286   BAROLY Non Stick Fraying Pan\n\n 100% ORIGINAL...
# 1716    CLOTH WARDROBE \n\nየብረቱ የልብስ ቁም ሳጥን\n1.05ሜትር...
# 4265  DELCASA ፔርሙዝ ማግ\n ትኩሱን ትኩስ\n ቀዝቃዛውን ቀዝቃዛ \n ለጉ...
# 2376                                   PEPPER HAND MILL
# 1212  Collapsable Large Capacity Dispenser\n\n ይሄንን ...
# 5656  ለክቡራንና ክቡራት ደንበኞቻችን ዕቃ ማዘዣ አድራሻችንን ስለቀየርን በዛሬ ...
# 3975  Saachi Juicer(100% original)\nSaachi የጁስ መፍጪያ\...
# 2297   SuTai  Original Electric Kettle \n2.3 ሊትር  አን...
# 3748  Classic Ceramic complet\n ለሾርባና ገንፎ ማቅረቢያ የሚፈለ...
# 4587  በቻርጅ የሚሰራ የጃር ውሃ ፓምፕ\n 450 birr\n0911928738\nመ...
# 2644   Cake Making Equipments Package\n\n አንድ 260Wat...
#
#                                         Labeled_Message
# 1332  ልዩ O\nየበዓል O\nቅናሽ O\nAcrylic O\nSalad O\nBowel...
# 3968  0904944848 B-PRICE\n0911928738 B-PRICE\n@order...
# 2023  Room O\nHumidifier O\n2 B-PRICE\nሊትር O\nይይዛል O...
# 5162  4.2 B-PRICE\nሊትር O\nመጠን O\nያለውን O\nማንኛውንም O\nጥ...
# 1131  Non O\nStick O\nCREPE O\nMAKER O\nየቂጣ O\nመጋገሪያ...
# 144   SILVER O\nCREST O\nMULTIFUNCTIONAL O\nKITCHEN ...
# 2128  Kitchen O\nMicro O\nFiber O\nTowel O\nየኪችን O\n...
# 1358  Sonifer O\n2 B-PRICE\nin O\n1 B-PRICE\nJuice O...
# 4136  Foot O\nbath O\nand O\nMassager O\nየእግር O\nማጠቢ...
# 4331  የካቻፕ O\nመቀነሻ O\n150 B-PRICE\nብር B-PRICE\n@orde...
# 2647  Circular O\nMosquito O\nNet O\nክብ O\nአጎበር O\nቢ...
# 516                     መልካም O\nየዕረፍት O\nቀን O\nይሁንልዎት O
# 3119  Wass O\nMitad O\nዋስ O\nምጣድ O\n16 B-PRICE\ninch...
# 834   Creative O\n6 B-PRICE\nlayer O\nShoe O\nRack O...
# 4996  htc O\npressure O\ncooker O\n100% O\nከአልሙኒየም O...
# 2880                            TOBI O\nSTEAM O\nIRON O
# 3485  Kitchen O\nTools O\nOrganizer O\nየማንኪያ O\nሹካና ...
# 3082  DOUBLE O\nSIDE O\nFRAYING O\nPAN O\nከሴራሚክ O\nየ...
# 2333  Bright O\nRound O\nOven O\nየዳቦ O\nመጋገሪያ O\n3 B...
# 286   BAROLY O\nNon O\nStick O\nFraying O\nPan O\n10...
# 1716  CLOTH O\nWARDROBE O\nየብረቱ O\nየልብስ O\nቁም O\nሳጥን...
# 4265  DELCASA O\nፔርሙዝ O\nማግ O\nትኩሱን O\nትኩስ O\nቀዝቃዛውን...
# 2376                           PEPPER O\nHAND O\nMILL O
# 1212  Collapsable O\nLarge O\nCapacity O\nDispenser ...
# 5656  ለክቡራንና O\nክቡራት O\nደንበኞቻችን O\nዕቃ O\nማዘዣ O\nአድራሻ...
# 3975  Saachi O\nJuicer(100% O\noriginal) O\nSaachi O...
# 2297  SuTai O\nOriginal O\nElectric O\nKettle O\n2.3...
# 3748  Classic O\nCeramic O\ncomplet O\nለሾርባና O\nገንፎ ...
# 4587  በቻርጅ O\nየሚሰራ O\nየጃር O\nውሃ O\nፓምፕ O\n450 B-PRIC...
# 2644  Cake O\nMaking O\nEquipments O\nPackage O\nአንድ...
# Labeled data saved to labeled_telegram_product_price_location.txt
